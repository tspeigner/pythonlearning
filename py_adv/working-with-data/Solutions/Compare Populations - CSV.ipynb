# %% [markdown]
# # Compare Populations - CSV

# %%
import csv

def compare_pops(pops, age_sex_year1, age_sex_year2):
    '''Finds the populations (pop1 and pop2) for the two 
    passed-in age, sex, and year tuples.
    
    Returns a two-item tuple containing:
     - the numeric difference in population (pop2 - pop1)
     - the ratio (pop2 / pop1)

    Keyword arguments:
    pops -- a sequence holding dictionaries
    age_sex_year1 -- a tuple holding age, sex, and year values
    age_sex_year2 -- a tuple holding age, sex, and year values'''
    pop1, pop2 = -1, -1
    for row in pops:
        if (row['AGE'] == str(age_sex_year1[0]) and row['SEX'] == age_sex_year1[1]):
            pop1 = row['POPESTIMATE' + str(age_sex_year1[2])]
            pop1 = int(pop1.replace(',',''))
        if (row['AGE'] == str(age_sex_year2[0]) and row['SEX'] == age_sex_year2[1]):
            pop2 = row['POPESTIMATE' + str(age_sex_year2[2])]
            pop2 = int(pop2.replace(',',''))
        if pop1 > 0 and pop2 > 0:
            return (pop2 - pop1, pop2/pop1)

with open('../csvs/us-population-2010-2014.csv', newline='') as csvfile:
    pops = list(csv.DictReader(csvfile))
    
pop1 = (30, 'M', 2011)
pop2 = (30, 'F', 2011)

diff = compare_pops(pops, pop1, pop2)
print(diff)
# Out:
# (-10353, 0.9951139373368245)

# %%
pops
# Out:
# [OrderedDict([('SEX', 'A'),
#               ('AGE', '0'),
#               ('POPESTIMATE2010', '3,951,330'),
#               ('POPESTIMATE2011', '3,963,071'),
#               ('POPESTIMATE2012', '3,926,665'),
#               ('POPESTIMATE2013', '3,945,610'),
#               ('POPESTIMATE2014', '3,948,350')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '1'),
#               ('POPESTIMATE2010', '3,957,888'),
#               ('POPESTIMATE2011', '3,966,510'),
#               ('POPESTIMATE2012', '3,978,006'),
#               ('POPESTIMATE2013', '3,943,077'),
#               ('POPESTIMATE2014', '3,962,123')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '2'),
#               ('POPESTIMATE2010', '4,090,862'),
#               ('POPESTIMATE2011', '3,971,573'),
#               ('POPESTIMATE2012', '3,979,952'),
#               ('POPESTIMATE2013', '3,992,690'),
#               ('POPESTIMATE2014', '3,957,772')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '3'),
#               ('POPESTIMATE2010', '4,111,920'),
#               ('POPESTIMATE2011', '4,102,501'),
#               ('POPESTIMATE2012', '3,983,049'),
#               ('POPESTIMATE2013', '3,992,425'),
#               ('POPESTIMATE2014', '4,005,190')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '4'),
#               ('POPESTIMATE2010', '4,077,552'),
#               ('POPESTIMATE2011', '4,122,303'),
#               ('POPESTIMATE2012', '4,112,638'),
#               ('POPESTIMATE2013', '3,994,047'),
#               ('POPESTIMATE2014', '4,003,448')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '5'),
#               ('POPESTIMATE2010', '4,064,653'),
#               ('POPESTIMATE2011', '4,087,713'),
#               ('POPESTIMATE2012', '4,132,210'),
#               ('POPESTIMATE2013', '4,123,408'),
#               ('POPESTIMATE2014', '4,004,858')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '6'),
#               ('POPESTIMATE2010', '4,073,013'),
#               ('POPESTIMATE2011', '4,074,979'),
#               ('POPESTIMATE2012', '4,097,780'),
#               ('POPESTIMATE2013', '4,143,094'),
#               ('POPESTIMATE2014', '4,134,352')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '7'),
#               ('POPESTIMATE2010', '4,043,047'),
#               ('POPESTIMATE2011', '4,083,240'),
#               ('POPESTIMATE2012', '4,084,964'),
#               ('POPESTIMATE2013', '4,108,615'),
#               ('POPESTIMATE2014', '4,154,000')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '8'),
#               ('POPESTIMATE2010', '4,025,604'),
#               ('POPESTIMATE2011', '4,053,206'),
#               ('POPESTIMATE2012', '4,093,213'),
#               ('POPESTIMATE2013', '4,095,827'),
#               ('POPESTIMATE2014', '4,119,524')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '9'),
#               ('POPESTIMATE2010', '4,125,415'),
#               ('POPESTIMATE2011', '4,035,769'),
#               ('POPESTIMATE2012', '4,063,193'),
#               ('POPESTIMATE2013', '4,104,133'),
#               ('POPESTIMATE2014', '4,106,832')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '10'),
#               ('POPESTIMATE2010', '4,187,063'),
#               ('POPESTIMATE2011', '4,135,617'),
#               ('POPESTIMATE2012', '4,045,840'),
#               ('POPESTIMATE2013', '4,074,206'),
#               ('POPESTIMATE2014', '4,115,254')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '11'),
#               ('POPESTIMATE2010', '4,115,511'),
#               ('POPESTIMATE2011', '4,197,472'),
#               ('POPESTIMATE2012', '4,145,919'),
#               ('POPESTIMATE2013', '4,057,128'),
#               ('POPESTIMATE2014', '4,085,636')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '12'),
#               ('POPESTIMATE2010', '4,113,280'),
#               ('POPESTIMATE2011', '4,126,168'),
#               ('POPESTIMATE2012', '4,208,013'),
#               ('POPESTIMATE2013', '4,157,449'),
#               ('POPESTIMATE2014', '4,068,790')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '13'),
#               ('POPESTIMATE2010', '4,119,666'),
#               ('POPESTIMATE2011', '4,124,244'),
#               ('POPESTIMATE2012', '4,136,951'),
#               ('POPESTIMATE2013', '4,219,776'),
#               ('POPESTIMATE2014', '4,169,346')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '14'),
#               ('POPESTIMATE2010', '4,145,614'),
#               ('POPESTIMATE2011', '4,131,487'),
#               ('POPESTIMATE2012', '4,135,749'),
#               ('POPESTIMATE2013', '4,149,559'),
#               ('POPESTIMATE2014', '4,232,480')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '15'),
#               ('POPESTIMATE2010', '4,231,003'),
#               ('POPESTIMATE2011', '4,158,977'),
#               ('POPESTIMATE2012', '4,144,326'),
#               ('POPESTIMATE2013', '4,149,781'),
#               ('POPESTIMATE2014', '4,163,723')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '16'),
#               ('POPESTIMATE2010', '4,313,252'),
#               ('POPESTIMATE2011', '4,247,472'),
#               ('POPESTIMATE2012', '4,174,855'),
#               ('POPESTIMATE2013', '4,161,624'),
#               ('POPESTIMATE2014', '4,167,234')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '17'),
#               ('POPESTIMATE2010', '4,376,368'),
#               ('POPESTIMATE2011', '4,334,957'),
#               ('POPESTIMATE2012', '4,268,503'),
#               ('POPESTIMATE2013', '4,197,758'),
#               ('POPESTIMATE2014', '4,184,706')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '18'),
#               ('POPESTIMATE2010', '4,491,005'),
#               ('POPESTIMATE2011', '4,402,634'),
#               ('POPESTIMATE2012', '4,360,345'),
#               ('POPESTIMATE2013', '4,296,134'),
#               ('POPESTIMATE2014', '4,225,590')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '19'),
#               ('POPESTIMATE2010', '4,571,385'),
#               ('POPESTIMATE2011', '4,520,683'),
#               ('POPESTIMATE2012', '4,430,960'),
#               ('POPESTIMATE2013', '4,390,087'),
#               ('POPESTIMATE2014', '4,326,394')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '20'),
#               ('POPESTIMATE2010', '4,568,470'),
#               ('POPESTIMATE2011', '4,600,421'),
#               ('POPESTIMATE2012', '4,550,552'),
#               ('POPESTIMATE2013', '4,459,958'),
#               ('POPESTIMATE2014', '4,418,887')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '21'),
#               ('POPESTIMATE2010', '4,387,914'),
#               ('POPESTIMATE2011', '4,596,145'),
#               ('POPESTIMATE2012', '4,633,178'),
#               ('POPESTIMATE2013', '4,580,949'),
#               ('POPESTIMATE2014', '4,489,746')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '22'),
#               ('POPESTIMATE2010', '4,286,987'),
#               ('POPESTIMATE2011', '4,415,297'),
#               ('POPESTIMATE2012', '4,628,678'),
#               ('POPESTIMATE2013', '4,666,392'),
#               ('POPESTIMATE2014', '4,612,322')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '23'),
#               ('POPESTIMATE2010', '4,217,221'),
#               ('POPESTIMATE2011', '4,314,751'),
#               ('POPESTIMATE2012', '4,447,266'),
#               ('POPESTIMATE2013', '4,661,403'),
#               ('POPESTIMATE2014', '4,698,584')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '24'),
#               ('POPESTIMATE2010', '4,243,589'),
#               ('POPESTIMATE2011', '4,244,542'),
#               ('POPESTIMATE2012', '4,346,226'),
#               ('POPESTIMATE2013', '4,479,243'),
#               ('POPESTIMATE2014', '4,692,635')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '25'),
#               ('POPESTIMATE2010', '4,289,424'),
#               ('POPESTIMATE2011', '4,269,956'),
#               ('POPESTIMATE2012', '4,275,655'),
#               ('POPESTIMATE2013', '4,377,385'),
#               ('POPESTIMATE2014', '4,509,594')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '26'),
#               ('POPESTIMATE2010', '4,160,810'),
#               ('POPESTIMATE2011', '4,313,805'),
#               ('POPESTIMATE2012', '4,299,059'),
#               ('POPESTIMATE2013', '4,305,217'),
#               ('POPESTIMATE2014', '4,406,472')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '27'),
#               ('POPESTIMATE2010', '4,237,010'),
#               ('POPESTIMATE2011', '4,183,474'),
#               ('POPESTIMATE2012', '4,340,038'),
#               ('POPESTIMATE2013', '4,326,704'),
#               ('POPESTIMATE2014', '4,332,545')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '28'),
#               ('POPESTIMATE2010', '4,247,540'),
#               ('POPESTIMATE2011', '4,258,146'),
#               ('POPESTIMATE2012', '4,207,330'),
#               ('POPESTIMATE2013', '4,364,812'),
#               ('POPESTIMATE2014', '4,351,851')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '29'),
#               ('POPESTIMATE2010', '4,210,285'),
#               ('POPESTIMATE2011', '4,266,588'),
#               ('POPESTIMATE2012', '4,280,142'),
#               ('POPESTIMATE2013', '4,230,048'),
#               ('POPESTIMATE2014', '4,387,476')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '30'),
#               ('POPESTIMATE2010', '4,304,244'),
#               ('POPESTIMATE2011', '4,227,415'),
#               ('POPESTIMATE2012', '4,285,874'),
#               ('POPESTIMATE2013', '4,300,627'),
#               ('POPESTIMATE2014', '4,250,780')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '31'),
#               ('POPESTIMATE2010', '4,042,507'),
#               ('POPESTIMATE2011', '4,319,572'),
#               ('POPESTIMATE2012', '4,244,611'),
#               ('POPESTIMATE2013', '4,303,694'),
#               ('POPESTIMATE2014', '4,318,706')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '32'),
#               ('POPESTIMATE2010', '3,967,603'),
#               ('POPESTIMATE2011', '4,055,955'),
#               ('POPESTIMATE2012', '4,335,235'),
#               ('POPESTIMATE2013', '4,261,256'),
#               ('POPESTIMATE2014', '4,320,072')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '33'),
#               ('POPESTIMATE2010', '3,933,570'),
#               ('POPESTIMATE2011', '3,980,018'),
#               ('POPESTIMATE2012', '4,069,723'),
#               ('POPESTIMATE2013', '4,349,928'),
#               ('POPESTIMATE2014', '4,276,113')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '34'),
#               ('POPESTIMATE2010', '3,822,188'),
#               ('POPESTIMATE2011', '3,944,620'),
#               ('POPESTIMATE2012', '3,992,611'),
#               ('POPESTIMATE2013', '4,082,539'),
#               ('POPESTIMATE2014', '4,362,895')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '35'),
#               ('POPESTIMATE2010', '3,948,318'),
#               ('POPESTIMATE2011', '3,832,502'),
#               ('POPESTIMATE2012', '3,955,942'),
#               ('POPESTIMATE2013', '4,004,456'),
#               ('POPESTIMATE2014', '4,094,039')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '36'),
#               ('POPESTIMATE2010', '3,830,202'),
#               ('POPESTIMATE2011', '3,957,029'),
#               ('POPESTIMATE2012', '3,842,263'),
#               ('POPESTIMATE2013', '3,965,564'),
#               ('POPESTIMATE2014', '4,014,413')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '37'),
#               ('POPESTIMATE2010', '3,896,776'),
#               ('POPESTIMATE2011', '3,837,814'),
#               ('POPESTIMATE2012', '3,965,664'),
#               ('POPESTIMATE2013', '3,851,119'),
#               ('POPESTIMATE2014', '3,974,190')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '38'),
#               ('POPESTIMATE2010', '4,080,229'),
#               ('POPESTIMATE2011', '3,903,277'),
#               ('POPESTIMATE2012', '3,845,503'),
#               ('POPESTIMATE2013', '3,973,390'),
#               ('POPESTIMATE2014', '3,859,181')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '39'),
#               ('POPESTIMATE2010', '4,324,460'),
#               ('POPESTIMATE2011', '4,085,771'),
#               ('POPESTIMATE2012', '3,909,207'),
#               ('POPESTIMATE2013', '3,851,949'),
#               ('POPESTIMATE2014', '3,979,827')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '40'),
#               ('POPESTIMATE2010', '4,387,483'),
#               ('POPESTIMATE2011', '4,327,743'),
#               ('POPESTIMATE2012', '4,090,134'),
#               ('POPESTIMATE2013', '3,913,982'),
#               ('POPESTIMATE2014', '3,856,888')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '41'),
#               ('POPESTIMATE2010', '4,163,470'),
#               ('POPESTIMATE2011', '4,388,941'),
#               ('POPESTIMATE2012', '4,330,257'),
#               ('POPESTIMATE2013', '4,093,483'),
#               ('POPESTIMATE2014', '3,917,413')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '42'),
#               ('POPESTIMATE2010', '4,082,733'),
#               ('POPESTIMATE2011', '4,164,004'),
#               ('POPESTIMATE2012', '4,390,026'),
#               ('POPESTIMATE2013', '4,331,851'),
#               ('POPESTIMATE2014', '4,095,929')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '43'),
#               ('POPESTIMATE2010', '4,093,841'),
#               ('POPESTIMATE2011', '4,082,479'),
#               ('POPESTIMATE2012', '4,164,073'),
#               ('POPESTIMATE2013', '4,389,840'),
#               ('POPESTIMATE2014', '4,332,491')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '44'),
#               ('POPESTIMATE2010', '4,178,501'),
#               ('POPESTIMATE2011', '4,092,604'),
#               ('POPESTIMATE2012', '4,081,719'),
#               ('POPESTIMATE2013', '4,163,387'),
#               ('POPESTIMATE2014', '4,388,762')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '45'),
#               ('POPESTIMATE2010', '4,438,551'),
#               ('POPESTIMATE2011', '4,175,439'),
#               ('POPESTIMATE2012', '4,090,411'),
#               ('POPESTIMATE2013', '4,079,605'),
#               ('POPESTIMATE2014', '4,161,450')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '46'),
#               ('POPESTIMATE2010', '4,529,712'),
#               ('POPESTIMATE2011', '4,433,594'),
#               ('POPESTIMATE2012', '4,171,208'),
#               ('POPESTIMATE2013', '4,086,799'),
#               ('POPESTIMATE2014', '4,076,237')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '47'),
#               ('POPESTIMATE2010', '4,535,464'),
#               ('POPESTIMATE2011', '4,522,493'),
#               ('POPESTIMATE2012', '4,427,137'),
#               ('POPESTIMATE2013', '4,165,962'),
#               ('POPESTIMATE2014', '4,082,150')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '48'),
#               ('POPESTIMATE2010', '4,534,669'),
#               ('POPESTIMATE2011', '4,526,007'),
#               ('POPESTIMATE2012', '4,513,643'),
#               ('POPESTIMATE2013', '4,418,934'),
#               ('POPESTIMATE2014', '4,158,996')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '49'),
#               ('POPESTIMATE2010', '4,599,102'),
#               ('POPESTIMATE2011', '4,523,366'),
#               ('POPESTIMATE2012', '4,515,116'),
#               ('POPESTIMATE2013', '4,503,246'),
#               ('POPESTIMATE2014', '4,409,209')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '50'),
#               ('POPESTIMATE2010', '4,646,251'),
#               ('POPESTIMATE2011', '4,585,728'),
#               ('POPESTIMATE2012', '4,510,701'),
#               ('POPESTIMATE2013', '4,502,720'),
#               ('POPESTIMATE2014', '4,491,431')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '51'),
#               ('POPESTIMATE2010', '4,498,994'),
#               ('POPESTIMATE2011', '4,631,187'),
#               ('POPESTIMATE2012', '4,570,693'),
#               ('POPESTIMATE2013', '4,496,145'),
#               ('POPESTIMATE2014', '4,488,666')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '52'),
#               ('POPESTIMATE2010', '4,480,630'),
#               ('POPESTIMATE2011', '4,482,274'),
#               ('POPESTIMATE2012', '4,613,986'),
#               ('POPESTIMATE2013', '4,553,710'),
#               ('POPESTIMATE2014', '4,480,175')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '53'),
#               ('POPESTIMATE2010', '4,439,422'),
#               ('POPESTIMATE2011', '4,462,028'),
#               ('POPESTIMATE2012', '4,463,630'),
#               ('POPESTIMATE2013', '4,595,211'),
#               ('POPESTIMATE2014', '4,535,748')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '54'),
#               ('POPESTIMATE2010', '4,288,475'),
#               ('POPESTIMATE2011', '4,419,019'),
#               ('POPESTIMATE2012', '4,441,593'),
#               ('POPESTIMATE2013', '4,443,510'),
#               ('POPESTIMATE2014', '4,574,789')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '55'),
#               ('POPESTIMATE2010', '4,259,012'),
#               ('POPESTIMATE2011', '4,266,705'),
#               ('POPESTIMATE2012', '4,396,537'),
#               ('POPESTIMATE2013', '4,419,299'),
#               ('POPESTIMATE2014', '4,421,625')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '56'),
#               ('POPESTIMATE2010', '4,093,161'),
#               ('POPESTIMATE2011', '4,236,097'),
#               ('POPESTIMATE2012', '4,243,307'),
#               ('POPESTIMATE2013', '4,372,416'),
#               ('POPESTIMATE2014', '4,395,471')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '57'),
#               ('POPESTIMATE2010', '3,946,548'),
#               ('POPESTIMATE2011', '4,069,059'),
#               ('POPESTIMATE2012', '4,211,174'),
#               ('POPESTIMATE2013', '4,218,311'),
#               ('POPESTIMATE2014', '4,347,179')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '58'),
#               ('POPESTIMATE2010', '3,802,467'),
#               ('POPESTIMATE2011', '3,921,318'),
#               ('POPESTIMATE2012', '4,043,248'),
#               ('POPESTIMATE2013', '4,184,160'),
#               ('POPESTIMATE2014', '4,191,757')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '59'),
#               ('POPESTIMATE2010', '3,694,276'),
#               ('POPESTIMATE2011', '3,776,136'),
#               ('POPESTIMATE2012', '3,894,493'),
#               ('POPESTIMATE2013', '4,015,049'),
#               ('POPESTIMATE2014', '4,155,417')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '60'),
#               ('POPESTIMATE2010', '3,616,733'),
#               ('POPESTIMATE2011', '3,667,142'),
#               ('POPESTIMATE2012', '3,748,044'),
#               ('POPESTIMATE2013', '3,865,188'),
#               ('POPESTIMATE2014', '3,985,367')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '61'),
#               ('POPESTIMATE2010', '3,520,121'),
#               ('POPESTIMATE2011', '3,588,516'),
#               ('POPESTIMATE2012', '3,637,748'),
#               ('POPESTIMATE2013', '3,717,715'),
#               ('POPESTIMATE2014', '3,834,428')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '62'),
#               ('POPESTIMATE2010', '3,495,073'),
#               ('POPESTIMATE2011', '3,489,637'),
#               ('POPESTIMATE2012', '3,557,701'),
#               ('POPESTIMATE2013', '3,605,936'),
#               ('POPESTIMATE2014', '3,685,822')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '63'),
#               ('POPESTIMATE2010', '3,652,174'),
#               ('POPESTIMATE2011', '3,461,414'),
#               ('POPESTIMATE2012', '3,456,782'),
#               ('POPESTIMATE2013', '3,523,891'),
#               ('POPESTIMATE2014', '3,572,379')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '64'),
#               ('POPESTIMATE2010', '2,706,063'),
#               ('POPESTIMATE2011', '3,614,400'),
#               ('POPESTIMATE2012', '3,425,920'),
#               ('POPESTIMATE2013', '3,421,079'),
#               ('POPESTIMATE2014', '3,488,136')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '65'),
#               ('POPESTIMATE2010', '2,678,532'),
#               ('POPESTIMATE2011', '2,675,970'),
#               ('POPESTIMATE2012', '3,574,806'),
#               ('POPESTIMATE2013', '3,388,166'),
#               ('POPESTIMATE2014', '3,384,449')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '66'),
#               ('POPESTIMATE2010', '2,621,346'),
#               ('POPESTIMATE2011', '2,646,389'),
#               ('POPESTIMATE2012', '2,644,091'),
#               ('POPESTIMATE2013', '3,531,557'),
#               ('POPESTIMATE2014', '3,347,776')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '67'),
#               ('POPESTIMATE2010', '2,693,709'),
#               ('POPESTIMATE2011', '2,586,335'),
#               ('POPESTIMATE2012', '2,612,156'),
#               ('POPESTIMATE2013', '2,609,726'),
#               ('POPESTIMATE2014', '3,485,502')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '68'),
#               ('POPESTIMATE2010', '2,359,819'),
#               ('POPESTIMATE2011', '2,654,140'),
#               ('POPESTIMATE2012', '2,548,804'),
#               ('POPESTIMATE2013', '2,574,784'),
#               ('POPESTIMATE2014', '2,572,527')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '69'),
#               ('POPESTIMATE2010', '2,167,833'),
#               ('POPESTIMATE2011', '2,321,963'),
#               ('POPESTIMATE2012', '2,612,207'),
#               ('POPESTIMATE2013', '2,508,782'),
#               ('POPESTIMATE2014', '2,535,012')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '70'),
#               ('POPESTIMATE2010', '2,062,581'),
#               ('POPESTIMATE2011', '2,129,733'),
#               ('POPESTIMATE2012', '2,282,169'),
#               ('POPESTIMATE2013', '2,567,340'),
#               ('POPESTIMATE2014', '2,466,485')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '71'),
#               ('POPESTIMATE2010', '1,953,614'),
#               ('POPESTIMATE2011', '2,023,019'),
#               ('POPESTIMATE2012', '2,090,057'),
#               ('POPESTIMATE2013', '2,239,534'),
#               ('POPESTIMATE2014', '2,519,748')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '72'),
#               ('POPESTIMATE2010', '1,883,821'),
#               ('POPESTIMATE2011', '1,912,459'),
#               ('POPESTIMATE2012', '1,981,768'),
#               ('POPESTIMATE2013', '2,047,549'),
#               ('POPESTIMATE2014', '2,194,234')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '73'),
#               ('POPESTIMATE2010', '1,750,309'),
#               ('POPESTIMATE2011', '1,840,179'),
#               ('POPESTIMATE2012', '1,869,510'),
#               ('POPESTIMATE2013', '1,937,455'),
#               ('POPESTIMATE2014', '2,002,191')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '74'),
#               ('POPESTIMATE2010', '1,685,999'),
#               ('POPESTIMATE2011', '1,705,665'),
#               ('POPESTIMATE2012', '1,794,816'),
#               ('POPESTIMATE2013', '1,823,535'),
#               ('POPESTIMATE2014', '1,890,366')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '75'),
#               ('POPESTIMATE2010', '1,631,879'),
#               ('POPESTIMATE2011', '1,638,735'),
#               ('POPESTIMATE2012', '1,659,415'),
#               ('POPESTIMATE2013', '1,746,314'),
#               ('POPESTIMATE2014', '1,774,697')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '76'),
#               ('POPESTIMATE2010', '1,481,683'),
#               ('POPESTIMATE2011', '1,581,387'),
#               ('POPESTIMATE2012', '1,589,617'),
#               ('POPESTIMATE2013', '1,609,791'),
#               ('POPESTIMATE2014', '1,694,648')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '77'),
#               ('POPESTIMATE2010', '1,449,173'),
#               ('POPESTIMATE2011', '1,430,885'),
#               ('POPESTIMATE2012', '1,529,072'),
#               ('POPESTIMATE2013', '1,537,153'),
#               ('POPESTIMATE2014', '1,557,239')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '78'),
#               ('POPESTIMATE2010', '1,402,184'),
#               ('POPESTIMATE2011', '1,394,601'),
#               ('POPESTIMATE2012', '1,378,456'),
#               ('POPESTIMATE2013', '1,473,161'),
#               ('POPESTIMATE2014', '1,481,505')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '79'),
#               ('POPESTIMATE2010', '1,354,913'),
#               ('POPESTIMATE2011', '1,343,759'),
#               ('POPESTIMATE2012', '1,338,342'),
#               ('POPESTIMATE2013', '1,322,661'),
#               ('POPESTIMATE2014', '1,414,235')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '80'),
#               ('POPESTIMATE2010', '1,319,725'),
#               ('POPESTIMATE2011', '1,292,479'),
#               ('POPESTIMATE2012', '1,283,654'),
#               ('POPESTIMATE2013', '1,278,653'),
#               ('POPESTIMATE2014', '1,264,072')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '81'),
#               ('POPESTIMATE2010', '1,212,603'),
#               ('POPESTIMATE2011', '1,252,515'),
#               ('POPESTIMATE2012', '1,228,370'),
#               ('POPESTIMATE2013', '1,219,980'),
#               ('POPESTIMATE2014', '1,216,009')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '82'),
#               ('POPESTIMATE2010', '1,158,352'),
#               ('POPESTIMATE2011', '1,143,972'),
#               ('POPESTIMATE2012', '1,183,753'),
#               ('POPESTIMATE2013', '1,160,857'),
#               ('POPESTIMATE2014', '1,153,634')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '83'),
#               ('POPESTIMATE2010', '1,081,442'),
#               ('POPESTIMATE2011', '1,085,393'),
#               ('POPESTIMATE2012', '1,073,879'),
#               ('POPESTIMATE2013', '1,111,333'),
#               ('POPESTIMATE2014', '1,090,465')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '84'),
#               ('POPESTIMATE2010', '987,026'),
#               ('POPESTIMATE2011', '1,005,439'),
#               ('POPESTIMATE2012', '1,011,221'),
#               ('POPESTIMATE2013', '1,000,403'),
#               ('POPESTIMATE2014', '1,036,186')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '85'),
#               ('POPESTIMATE2010', '915,015'),
#               ('POPESTIMATE2011', '909,449'),
#               ('POPESTIMATE2012', '928,851'),
#               ('POPESTIMATE2013', '934,211'),
#               ('POPESTIMATE2014', '924,969')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '86'),
#               ('POPESTIMATE2010', '821,550'),
#               ('POPESTIMATE2011', '835,003'),
#               ('POPESTIMATE2012', '832,128'),
#               ('POPESTIMATE2013', '850,026'),
#               ('POPESTIMATE2014', '855,696')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '87'),
#               ('POPESTIMATE2010', '721,195'),
#               ('POPESTIMATE2011', '741,557'),
#               ('POPESTIMATE2012', '756,235'),
#               ('POPESTIMATE2013', '753,560'),
#               ('POPESTIMATE2014', '770,685')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '88'),
#               ('POPESTIMATE2010', '636,657'),
#               ('POPESTIMATE2011', '643,272'),
#               ('POPESTIMATE2012', '663,894'),
#               ('POPESTIMATE2013', '677,229'),
#               ('POPESTIMATE2014', '675,487')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '89'),
#               ('POPESTIMATE2010', '546,193'),
#               ('POPESTIMATE2011', '560,102'),
#               ('POPESTIMATE2012', '568,779'),
#               ('POPESTIMATE2013', '587,159'),
#               ('POPESTIMATE2014', '599,834')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '90'),
#               ('POPESTIMATE2010', '448,323'),
#               ('POPESTIMATE2011', '473,899'),
#               ('POPESTIMATE2012', '488,100'),
#               ('POPESTIMATE2013', '496,118'),
#               ('POPESTIMATE2014', '512,845')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '91'),
#               ('POPESTIMATE2010', '344,443'),
#               ('POPESTIMATE2011', '382,686'),
#               ('POPESTIMATE2012', '407,002'),
#               ('POPESTIMATE2013', '419,045'),
#               ('POPESTIMATE2014', '426,946')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '92'),
#               ('POPESTIMATE2010', '288,841'),
#               ('POPESTIMATE2011', '289,272'),
#               ('POPESTIMATE2012', '323,068'),
#               ('POPESTIMATE2013', '344,040'),
#               ('POPESTIMATE2014', '354,532')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '93'),
#               ('POPESTIMATE2010', '219,063'),
#               ('POPESTIMATE2011', '238,069'),
#               ('POPESTIMATE2012', '240,255'),
#               ('POPESTIMATE2013', '268,022'),
#               ('POPESTIMATE2014', '286,333')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '94'),
#               ('POPESTIMATE2010', '170,775'),
#               ('POPESTIMATE2011', '176,699'),
#               ('POPESTIMATE2012', '193,908'),
#               ('POPESTIMATE2013', '196,079'),
#               ('POPESTIMATE2014', '218,655')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '95'),
#               ('POPESTIMATE2010', '131,077'),
#               ('POPESTIMATE2011', '135,059'),
#               ('POPESTIMATE2012', '140,737'),
#               ('POPESTIMATE2013', '154,790'),
#               ('POPESTIMATE2014', '157,124')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '96'),
#               ('POPESTIMATE2010', '97,161'),
#               ('POPESTIMATE2011', '101,256'),
#               ('POPESTIMATE2012', '105,454'),
#               ('POPESTIMATE2013', '109,697'),
#               ('POPESTIMATE2014', '121,184')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '97'),
#               ('POPESTIMATE2010', '68,893'),
#               ('POPESTIMATE2011', '73,279'),
#               ('POPESTIMATE2012', '77,180'),
#               ('POPESTIMATE2013', '80,524'),
#               ('POPESTIMATE2014', '83,731')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '98'),
#               ('POPESTIMATE2010', '47,037'),
#               ('POPESTIMATE2011', '50,665'),
#               ('POPESTIMATE2012', '54,530'),
#               ('POPESTIMATE2013', '57,453'),
#               ('POPESTIMATE2014', '60,185')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '99'),
#               ('POPESTIMATE2010', '32,178'),
#               ('POPESTIMATE2011', '33,641'),
#               ('POPESTIMATE2012', '36,780'),
#               ('POPESTIMATE2013', '39,606'),
#               ('POPESTIMATE2014', '41,828')]),
#  OrderedDict([('SEX', 'A'),
#               ('AGE', '100'),
#               ('POPESTIMATE2010', '54,409'),
#               ('POPESTIMATE2011', '57,703'),
#               ('POPESTIMATE2012', '61,845'),
#               ('POPESTIMATE2013', '66,748'),
#               ('POPESTIMATE2014', '72,197')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '0'),
#               ('POPESTIMATE2010', '2,018,420'),
#               ('POPESTIMATE2011', '2,028,434'),
#               ('POPESTIMATE2012', '2,007,693'),
#               ('POPESTIMATE2013', '2,015,537'),
#               ('POPESTIMATE2014', '2,017,857')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '1'),
#               ('POPESTIMATE2010', '2,020,332'),
#               ('POPESTIMATE2011', '2,025,493'),
#               ('POPESTIMATE2012', '2,035,380'),
#               ('POPESTIMATE2013', '2,015,352'),
#               ('POPESTIMATE2014', '2,023,253')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '2'),
#               ('POPESTIMATE2010', '2,088,685'),
#               ('POPESTIMATE2011', '2,026,975'),
#               ('POPESTIMATE2012', '2,032,008'),
#               ('POPESTIMATE2013', '2,042,522'),
#               ('POPESTIMATE2014', '2,022,502')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '3'),
#               ('POPESTIMATE2010', '2,101,272'),
#               ('POPESTIMATE2011', '2,094,310'),
#               ('POPESTIMATE2012', '2,032,562'),
#               ('POPESTIMATE2013', '2,038,085'),
#               ('POPESTIMATE2014', '2,048,618')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '4'),
#               ('POPESTIMATE2010', '2,084,312'),
#               ('POPESTIMATE2011', '2,106,354'),
#               ('POPESTIMATE2012', '2,099,244'),
#               ('POPESTIMATE2013', '2,037,953'),
#               ('POPESTIMATE2014', '2,043,498')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '5'),
#               ('POPESTIMATE2010', '2,076,573'),
#               ('POPESTIMATE2011', '2,089,461'),
#               ('POPESTIMATE2012', '2,111,381'),
#               ('POPESTIMATE2013', '2,104,725'),
#               ('POPESTIMATE2014', '2,043,467')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '6'),
#               ('POPESTIMATE2010', '2,079,410'),
#               ('POPESTIMATE2011', '2,081,802'),
#               ('POPESTIMATE2012', '2,094,576'),
#               ('POPESTIMATE2013', '2,116,922'),
#               ('POPESTIMATE2014', '2,110,328')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '7'),
#               ('POPESTIMATE2010', '2,063,139'),
#               ('POPESTIMATE2011', '2,084,356'),
#               ('POPESTIMATE2012', '2,086,621'),
#               ('POPESTIMATE2013', '2,099,841'),
#               ('POPESTIMATE2014', '2,122,240')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '8'),
#               ('POPESTIMATE2010', '2,054,462'),
#               ('POPESTIMATE2011', '2,067,977'),
#               ('POPESTIMATE2012', '2,089,102'),
#               ('POPESTIMATE2013', '2,091,869'),
#               ('POPESTIMATE2014', '2,105,122')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '9'),
#               ('POPESTIMATE2010', '2,107,037'),
#               ('POPESTIMATE2011', '2,059,312'),
#               ('POPESTIMATE2012', '2,072,752'),
#               ('POPESTIMATE2013', '2,094,425'),
#               ('POPESTIMATE2014', '2,097,272')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '10'),
#               ('POPESTIMATE2010', '2,142,168'),
#               ('POPESTIMATE2011', '2,111,886'),
#               ('POPESTIMATE2012', '2,064,128'),
#               ('POPESTIMATE2013', '2,078,108'),
#               ('POPESTIMATE2014', '2,099,874')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '11'),
#               ('POPESTIMATE2010', '2,104,797'),
#               ('POPESTIMATE2011', '2,147,112'),
#               ('POPESTIMATE2012', '2,116,780'),
#               ('POPESTIMATE2013', '2,069,595'),
#               ('POPESTIMATE2014', '2,083,687')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '12'),
#               ('POPESTIMATE2010', '2,103,650'),
#               ('POPESTIMATE2011', '2,109,811'),
#               ('POPESTIMATE2012', '2,152,093'),
#               ('POPESTIMATE2013', '2,122,312'),
#               ('POPESTIMATE2014', '2,075,243')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '13'),
#               ('POPESTIMATE2010', '2,104,949'),
#               ('POPESTIMATE2011', '2,108,976'),
#               ('POPESTIMATE2012', '2,115,010'),
#               ('POPESTIMATE2013', '2,157,858'),
#               ('POPESTIMATE2014', '2,128,187')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '14'),
#               ('POPESTIMATE2010', '2,122,913'),
#               ('POPESTIMATE2011', '2,110,785'),
#               ('POPESTIMATE2012', '2,114,607'),
#               ('POPESTIMATE2013', '2,121,285'),
#               ('POPESTIMATE2014', '2,164,228')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '15'),
#               ('POPESTIMATE2010', '2,170,442'),
#               ('POPESTIMATE2011', '2,129,579'),
#               ('POPESTIMATE2012', '2,117,125'),
#               ('POPESTIMATE2013', '2,121,660'),
#               ('POPESTIMATE2014', '2,128,424')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '16'),
#               ('POPESTIMATE2010', '2,215,032'),
#               ('POPESTIMATE2011', '2,179,123'),
#               ('POPESTIMATE2012', '2,137,897'),
#               ('POPESTIMATE2013', '2,126,276'),
#               ('POPESTIMATE2014', '2,130,938')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '17'),
#               ('POPESTIMATE2010', '2,252,838'),
#               ('POPESTIMATE2011', '2,226,783'),
#               ('POPESTIMATE2012', '2,190,437'),
#               ('POPESTIMATE2013', '2,150,277'),
#               ('POPESTIMATE2014', '2,138,809')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '18'),
#               ('POPESTIMATE2010', '2,305,733'),
#               ('POPESTIMATE2011', '2,266,716'),
#               ('POPESTIMATE2012', '2,240,121'),
#               ('POPESTIMATE2013', '2,205,027'),
#               ('POPESTIMATE2014', '2,165,062')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '19'),
#               ('POPESTIMATE2010', '2,334,906'),
#               ('POPESTIMATE2011', '2,321,580'),
#               ('POPESTIMATE2012', '2,281,573'),
#               ('POPESTIMATE2013', '2,255,477'),
#               ('POPESTIMATE2014', '2,220,790')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '20'),
#               ('POPESTIMATE2010', '2,331,846'),
#               ('POPESTIMATE2011', '2,350,022'),
#               ('POPESTIMATE2012', '2,337,541'),
#               ('POPESTIMATE2013', '2,296,103'),
#               ('POPESTIMATE2014', '2,269,570')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '21'),
#               ('POPESTIMATE2010', '2,241,095'),
#               ('POPESTIMATE2011', '2,345,467'),
#               ('POPESTIMATE2012', '2,368,174'),
#               ('POPESTIMATE2013', '2,352,872'),
#               ('POPESTIMATE2014', '2,310,734')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '22'),
#               ('POPESTIMATE2010', '2,188,228'),
#               ('POPESTIMATE2011', '2,253,415'),
#               ('POPESTIMATE2012', '2,362,560'),
#               ('POPESTIMATE2013', '2,385,044'),
#               ('POPESTIMATE2014', '2,367,842')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '23'),
#               ('POPESTIMATE2010', '2,151,095'),
#               ('POPESTIMATE2011', '2,199,885'),
#               ('POPESTIMATE2012', '2,269,242'),
#               ('POPESTIMATE2013', '2,378,020'),
#               ('POPESTIMATE2014', '2,399,883')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '24'),
#               ('POPESTIMATE2010', '2,161,380'),
#               ('POPESTIMATE2011', '2,162,004'),
#               ('POPESTIMATE2012', '2,214,632'),
#               ('POPESTIMATE2013', '2,283,478'),
#               ('POPESTIMATE2014', '2,391,398')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '25'),
#               ('POPESTIMATE2010', '2,177,171'),
#               ('POPESTIMATE2011', '2,171,072'),
#               ('POPESTIMATE2012', '2,176,181'),
#               ('POPESTIMATE2013', '2,227,806'),
#               ('POPESTIMATE2014', '2,295,836')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '26'),
#               ('POPESTIMATE2010', '2,102,375'),
#               ('POPESTIMATE2011', '2,185,901'),
#               ('POPESTIMATE2012', '2,184,318'),
#               ('POPESTIMATE2013', '2,188,750'),
#               ('POPESTIMATE2014', '2,240,026')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '27'),
#               ('POPESTIMATE2010', '2,135,214'),
#               ('POPESTIMATE2011', '2,110,648'),
#               ('POPESTIMATE2012', '2,197,584'),
#               ('POPESTIMATE2013', '2,196,457'),
#               ('POPESTIMATE2014', '2,200,429')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '28'),
#               ('POPESTIMATE2010', '2,135,020'),
#               ('POPESTIMATE2011', '2,142,935'),
#               ('POPESTIMATE2012', '2,121,224'),
#               ('POPESTIMATE2013', '2,208,102'),
#               ('POPESTIMATE2014', '2,207,185')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '29'),
#               ('POPESTIMATE2010', '2,112,348'),
#               ('POPESTIMATE2011', '2,142,142'),
#               ('POPESTIMATE2012', '2,153,004'),
#               ('POPESTIMATE2013', '2,131,034'),
#               ('POPESTIMATE2014', '2,217,913')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '30'),
#               ('POPESTIMATE2010', '2,167,540'),
#               ('POPESTIMATE2011', '2,118,884'),
#               ('POPESTIMATE2012', '2,150,930'),
#               ('POPESTIMATE2013', '2,161,949'),
#               ('POPESTIMATE2014', '2,140,108')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '31'),
#               ('POPESTIMATE2010', '2,026,467'),
#               ('POPESTIMATE2011', '2,173,437'),
#               ('POPESTIMATE2012', '2,126,666'),
#               ('POPESTIMATE2013', '2,158,691'),
#               ('POPESTIMATE2014', '2,169,725')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '32'),
#               ('POPESTIMATE2010', '1,986,185'),
#               ('POPESTIMATE2011', '2,031,439'),
#               ('POPESTIMATE2012', '2,180,655'),
#               ('POPESTIMATE2013', '2,134,119'),
#               ('POPESTIMATE2014', '2,165,840')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '33'),
#               ('POPESTIMATE2010', '1,963,676'),
#               ('POPESTIMATE2011', '1,990,895'),
#               ('POPESTIMATE2012', '2,037,597'),
#               ('POPESTIMATE2013', '2,187,122'),
#               ('POPESTIMATE2014', '2,140,697')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '34'),
#               ('POPESTIMATE2010', '1,908,761'),
#               ('POPESTIMATE2011', '1,967,591'),
#               ('POPESTIMATE2012', '1,996,443'),
#               ('POPESTIMATE2013', '2,042,822'),
#               ('POPESTIMATE2014', '2,192,455')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '35'),
#               ('POPESTIMATE2010', '1,974,660'),
#               ('POPESTIMATE2011', '1,912,408'),
#               ('POPESTIMATE2012', '1,972,476'),
#               ('POPESTIMATE2013', '2,001,196'),
#               ('POPESTIMATE2014', '2,047,326')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '36'),
#               ('POPESTIMATE2010', '1,907,447'),
#               ('POPESTIMATE2011', '1,977,556'),
#               ('POPESTIMATE2012', '1,916,441'),
#               ('POPESTIMATE2013', '1,976,017'),
#               ('POPESTIMATE2014', '2,004,990')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '37'),
#               ('POPESTIMATE2010', '1,934,572'),
#               ('POPESTIMATE2011', '1,909,891'),
#               ('POPESTIMATE2012', '1,981,177'),
#               ('POPESTIMATE2013', '1,919,755'),
#               ('POPESTIMATE2014', '1,979,035')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '38'),
#               ('POPESTIMATE2010', '2,028,088'),
#               ('POPESTIMATE2011', '1,936,430'),
#               ('POPESTIMATE2012', '1,913,007'),
#               ('POPESTIMATE2013', '1,983,827'),
#               ('POPESTIMATE2014', '1,922,571')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '39'),
#               ('POPESTIMATE2010', '2,148,755'),
#               ('POPESTIMATE2011', '2,029,620'),
#               ('POPESTIMATE2012', '1,938,450'),
#               ('POPESTIMATE2013', '1,915,150'),
#               ('POPESTIMATE2014', '1,985,914')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '40'),
#               ('POPESTIMATE2010', '2,189,556'),
#               ('POPESTIMATE2011', '2,148,816'),
#               ('POPESTIMATE2012', '2,030,700'),
#               ('POPESTIMATE2013', '1,939,565'),
#               ('POPESTIMATE2014', '1,916,261')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '41'),
#               ('POPESTIMATE2010', '2,073,925'),
#               ('POPESTIMATE2011', '2,188,440'),
#               ('POPESTIMATE2012', '2,148,912'),
#               ('POPESTIMATE2013', '2,031,098'),
#               ('POPESTIMATE2014', '1,939,916')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '42'),
#               ('POPESTIMATE2010', '2,031,830'),
#               ('POPESTIMATE2011', '2,072,644'),
#               ('POPESTIMATE2012', '2,187,877'),
#               ('POPESTIMATE2013', '2,148,528'),
#               ('POPESTIMATE2014', '2,031,325')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '43'),
#               ('POPESTIMATE2010', '2,031,012'),
#               ('POPESTIMATE2011', '2,030,258'),
#               ('POPESTIMATE2012', '2,071,530'),
#               ('POPESTIMATE2013', '2,186,337'),
#               ('POPESTIMATE2014', '2,147,656')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '44'),
#               ('POPESTIMATE2010', '2,074,606'),
#               ('POPESTIMATE2011', '2,028,884'),
#               ('POPESTIMATE2012', '2,028,587'),
#               ('POPESTIMATE2013', '2,069,691'),
#               ('POPESTIMATE2014', '2,184,235')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '45'),
#               ('POPESTIMATE2010', '2,201,934'),
#               ('POPESTIMATE2011', '2,071,315'),
#               ('POPESTIMATE2012', '2,026,505'),
#               ('POPESTIMATE2013', '2,025,995'),
#               ('POPESTIMATE2014', '2,067,223')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '46'),
#               ('POPESTIMATE2010', '2,238,804'),
#               ('POPESTIMATE2011', '2,197,676'),
#               ('POPESTIMATE2012', '2,067,816'),
#               ('POPESTIMATE2013', '2,023,165'),
#               ('POPESTIMATE2014', '2,022,698')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '47'),
#               ('POPESTIMATE2010', '2,237,972'),
#               ('POPESTIMATE2011', '2,233,282'),
#               ('POPESTIMATE2012', '2,192,918'),
#               ('POPESTIMATE2013', '2,063,499'),
#               ('POPESTIMATE2014', '2,019,306')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '48'),
#               ('POPESTIMATE2010', '2,235,326'),
#               ('POPESTIMATE2011', '2,231,035'),
#               ('POPESTIMATE2012', '2,226,963'),
#               ('POPESTIMATE2013', '2,186,890'),
#               ('POPESTIMATE2014', '2,058,243')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '49'),
#               ('POPESTIMATE2010', '2,262,482'),
#               ('POPESTIMATE2011', '2,227,361'),
#               ('POPESTIMATE2012', '2,223,569'),
#               ('POPESTIMATE2013', '2,219,697'),
#               ('POPESTIMATE2014', '2,179,993')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '50'),
#               ('POPESTIMATE2010', '2,290,902'),
#               ('POPESTIMATE2011', '2,253,317'),
#               ('POPESTIMATE2012', '2,218,886'),
#               ('POPESTIMATE2013', '2,215,048'),
#               ('POPESTIMATE2014', '2,211,607')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '51'),
#               ('POPESTIMATE2010', '2,209,830'),
#               ('POPESTIMATE2011', '2,280,590'),
#               ('POPESTIMATE2012', '2,243,135'),
#               ('POPESTIMATE2013', '2,208,963'),
#               ('POPESTIMATE2014', '2,205,405')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '52'),
#               ('POPESTIMATE2010', '2,197,222'),
#               ('POPESTIMATE2011', '2,198,558'),
#               ('POPESTIMATE2012', '2,269,096'),
#               ('POPESTIMATE2013', '2,231,681'),
#               ('POPESTIMATE2014', '2,198,124')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '53'),
#               ('POPESTIMATE2010', '2,170,965'),
#               ('POPESTIMATE2011', '2,184,619'),
#               ('POPESTIMATE2012', '2,186,145'),
#               ('POPESTIMATE2013', '2,256,425'),
#               ('POPESTIMATE2014', '2,219,617')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '54'),
#               ('POPESTIMATE2010', '2,091,677'),
#               ('POPESTIMATE2011', '2,157,278'),
#               ('POPESTIMATE2012', '2,171,174'),
#               ('POPESTIMATE2013', '2,172,782'),
#               ('POPESTIMATE2014', '2,242,828')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '55'),
#               ('POPESTIMATE2010', '2,075,250'),
#               ('POPESTIMATE2011', '2,077,204'),
#               ('POPESTIMATE2012', '2,142,478'),
#               ('POPESTIMATE2013', '2,156,419'),
#               ('POPESTIMATE2014', '2,158,258')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '56'),
#               ('POPESTIMATE2010', '1,984,480'),
#               ('POPESTIMATE2011', '2,059,951'),
#               ('POPESTIMATE2012', '2,061,826'),
#               ('POPESTIMATE2013', '2,126,682'),
#               ('POPESTIMATE2014', '2,140,722')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '57'),
#               ('POPESTIMATE2010', '1,910,028'),
#               ('POPESTIMATE2011', '1,968,594'),
#               ('POPESTIMATE2012', '2,043,497'),
#               ('POPESTIMATE2013', '2,045,443'),
#               ('POPESTIMATE2014', '2,110,149')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '58'),
#               ('POPESTIMATE2010', '1,838,703'),
#               ('POPESTIMATE2011', '1,893,322'),
#               ('POPESTIMATE2012', '1,951,737'),
#               ('POPESTIMATE2013', '2,025,729'),
#               ('POPESTIMATE2014', '2,027,959')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '59'),
#               ('POPESTIMATE2010', '1,779,504'),
#               ('POPESTIMATE2011', '1,821,406'),
#               ('POPESTIMATE2012', '1,875,818'),
#               ('POPESTIMATE2013', '1,933,300'),
#               ('POPESTIMATE2014', '2,006,900')]),
#  OrderedDict([('SEX', 'M'),
#               ('AGE', '60'),
# ...
#               ('POPESTIMATE2012', '2,103,392'),
#               ('POPESTIMATE2013', '2,063,634'),
#               ('POPESTIMATE2014', '2,053,539')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '47'),
#               ('POPESTIMATE2010', '2,297,492'),
#               ('POPESTIMATE2011', '2,289,211'),
#               ('POPESTIMATE2012', '2,234,219'),
#               ('POPESTIMATE2013', '2,102,463'),
#               ('POPESTIMATE2014', '2,062,844')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '48'),
#               ('POPESTIMATE2010', '2,299,343'),
#               ('POPESTIMATE2011', '2,294,972'),
#               ('POPESTIMATE2012', '2,286,680'),
#               ('POPESTIMATE2013', '2,232,044'),
#               ('POPESTIMATE2014', '2,100,753')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '49'),
#               ('POPESTIMATE2010', '2,336,620'),
#               ('POPESTIMATE2011', '2,296,005'),
#               ('POPESTIMATE2012', '2,291,547'),
#               ('POPESTIMATE2013', '2,283,549'),
#               ('POPESTIMATE2014', '2,229,216')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '50'),
#               ('POPESTIMATE2010', '2,355,349'),
#               ('POPESTIMATE2011', '2,332,411'),
#               ('POPESTIMATE2012', '2,291,815'),
#               ('POPESTIMATE2013', '2,287,672'),
#               ('POPESTIMATE2014', '2,279,824')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '51'),
#               ('POPESTIMATE2010', '2,289,164'),
#               ('POPESTIMATE2011', '2,350,597'),
#               ('POPESTIMATE2012', '2,327,558'),
#               ('POPESTIMATE2013', '2,287,182'),
#               ('POPESTIMATE2014', '2,283,261')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '52'),
#               ('POPESTIMATE2010', '2,283,408'),
#               ('POPESTIMATE2011', '2,283,716'),
#               ('POPESTIMATE2012', '2,344,890'),
#               ('POPESTIMATE2013', '2,322,029'),
#               ('POPESTIMATE2014', '2,282,051')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '53'),
#               ('POPESTIMATE2010', '2,268,457'),
#               ('POPESTIMATE2011', '2,277,409'),
#               ('POPESTIMATE2012', '2,277,485'),
#               ('POPESTIMATE2013', '2,338,786'),
#               ('POPESTIMATE2014', '2,316,131')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '54'),
#               ('POPESTIMATE2010', '2,196,798'),
#               ('POPESTIMATE2011', '2,261,741'),
#               ('POPESTIMATE2012', '2,270,419'),
#               ('POPESTIMATE2013', '2,270,728'),
#               ('POPESTIMATE2014', '2,331,961')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '55'),
#               ('POPESTIMATE2010', '2,183,762'),
#               ('POPESTIMATE2011', '2,189,501'),
#               ('POPESTIMATE2012', '2,254,059'),
#               ('POPESTIMATE2013', '2,262,880'),
#               ('POPESTIMATE2014', '2,263,367')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '56'),
#               ('POPESTIMATE2010', '2,108,681'),
#               ('POPESTIMATE2011', '2,176,146'),
#               ('POPESTIMATE2012', '2,181,481'),
#               ('POPESTIMATE2013', '2,245,734'),
#               ('POPESTIMATE2014', '2,254,749')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '57'),
#               ('POPESTIMATE2010', '2,036,520'),
#               ('POPESTIMATE2011', '2,100,465'),
#               ('POPESTIMATE2012', '2,167,677'),
#               ('POPESTIMATE2013', '2,172,868'),
#               ('POPESTIMATE2014', '2,237,030')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '58'),
#               ('POPESTIMATE2010', '1,963,764'),
#               ('POPESTIMATE2011', '2,027,996'),
#               ('POPESTIMATE2012', '2,091,511'),
#               ('POPESTIMATE2013', '2,158,431'),
#               ('POPESTIMATE2014', '2,163,798')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '59'),
#               ('POPESTIMATE2010', '1,914,772'),
#               ('POPESTIMATE2011', '1,954,730'),
#               ('POPESTIMATE2012', '2,018,675'),
#               ('POPESTIMATE2013', '2,081,749'),
#               ('POPESTIMATE2014', '2,148,517')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '60'),
#               ('POPESTIMATE2010', '1,874,501'),
#               ('POPESTIMATE2011', '1,905,437'),
#               ('POPESTIMATE2012', '1,944,896'),
#               ('POPESTIMATE2013', '2,008,381'),
#               ('POPESTIMATE2014', '2,071,358')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '61'),
#               ('POPESTIMATE2010', '1,828,708'),
#               ('POPESTIMATE2011', '1,864,446'),
#               ('POPESTIMATE2012', '1,894,984'),
#               ('POPESTIMATE2013', '1,934,028'),
#               ('POPESTIMATE2014', '1,997,348')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '62'),
#               ('POPESTIMATE2010', '1,815,999'),
#               ('POPESTIMATE2011', '1,817,279'),
#               ('POPESTIMATE2012', '1,853,114'),
#               ('POPESTIMATE2013', '1,883,242'),
#               ('POPESTIMATE2014', '1,922,318')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '63'),
#               ('POPESTIMATE2010', '1,898,260'),
#               ('POPESTIMATE2011', '1,803,163'),
#               ('POPESTIMATE2012', '1,804,647'),
#               ('POPESTIMATE2013', '1,840,391'),
#               ('POPESTIMATE2014', '1,870,552')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '64'),
#               ('POPESTIMATE2010', '1,414,220'),
#               ('POPESTIMATE2011', '1,883,433'),
#               ('POPESTIMATE2012', '1,789,331'),
#               ('POPESTIMATE2013', '1,791,001'),
#               ('POPESTIMATE2014', '1,826,662')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '65'),
#               ('POPESTIMATE2010', '1,405,839'),
#               ('POPESTIMATE2011', '1,402,532'),
#               ('POPESTIMATE2012', '1,867,893'),
#               ('POPESTIMATE2013', '1,774,686'),
#               ('POPESTIMATE2014', '1,776,761')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '66'),
#               ('POPESTIMATE2010', '1,381,541'),
#               ('POPESTIMATE2011', '1,393,059'),
#               ('POPESTIMATE2012', '1,389,902'),
#               ('POPESTIMATE2013', '1,850,730'),
#               ('POPESTIMATE2014', '1,758,649')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '67'),
#               ('POPESTIMATE2010', '1,423,561'),
#               ('POPESTIMATE2011', '1,367,316'),
#               ('POPESTIMATE2012', '1,379,412'),
#               ('POPESTIMATE2013', '1,376,207'),
#               ('POPESTIMATE2014', '1,832,245')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '68'),
#               ('POPESTIMATE2010', '1,254,117'),
#               ('POPESTIMATE2011', '1,407,347'),
#               ('POPESTIMATE2012', '1,351,919'),
#               ('POPESTIMATE2013', '1,364,098'),
#               ('POPESTIMATE2014', '1,361,047')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '69'),
#               ('POPESTIMATE2010', '1,161,047'),
#               ('POPESTIMATE2011', '1,238,294'),
#               ('POPESTIMATE2012', '1,389,792'),
#               ('POPESTIMATE2013', '1,335,136'),
#               ('POPESTIMATE2014', '1,347,458')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '70'),
#               ('POPESTIMATE2010', '1,108,505'),
#               ('POPESTIMATE2011', '1,144,782'),
#               ('POPESTIMATE2012', '1,221,255'),
#               ('POPESTIMATE2013', '1,370,786'),
#               ('POPESTIMATE2014', '1,317,238')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '71'),
#               ('POPESTIMATE2010', '1,050,351'),
#               ('POPESTIMATE2011', '1,091,436'),
#               ('POPESTIMATE2012', '1,127,688'),
#               ('POPESTIMATE2013', '1,202,985'),
#               ('POPESTIMATE2014', '1,350,392')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '72'),
#               ('POPESTIMATE2010', '1,021,293'),
#               ('POPESTIMATE2011', '1,032,476'),
#               ('POPESTIMATE2012', '1,073,478'),
#               ('POPESTIMATE2013', '1,109,174'),
#               ('POPESTIMATE2014', '1,183,338')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '73'),
#               ('POPESTIMATE2010', '955,663'),
#               ('POPESTIMATE2011', '1,002,064'),
#               ('POPESTIMATE2012', '1,013,648'),
#               ('POPESTIMATE2013', '1,053,964'),
#               ('POPESTIMATE2014', '1,089,183')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '74'),
#               ('POPESTIMATE2010', '927,168'),
#               ('POPESTIMATE2011', '935,657'),
#               ('POPESTIMATE2012', '981,819'),
#               ('POPESTIMATE2013', '993,220'),
#               ('POPESTIMATE2014', '1,032,934')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '75'),
#               ('POPESTIMATE2010', '906,215'),
#               ('POPESTIMATE2011', '905,706'),
#               ('POPESTIMATE2012', '914,717'),
#               ('POPESTIMATE2013', '959,933'),
#               ('POPESTIMATE2014', '971,263')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '76'),
#               ('POPESTIMATE2010', '828,132'),
#               ('POPESTIMATE2011', '882,889'),
#               ('POPESTIMATE2012', '883,089'),
#               ('POPESTIMATE2013', '891,909'),
#               ('POPESTIMATE2014', '936,270')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '77'),
#               ('POPESTIMATE2010', '818,306'),
#               ('POPESTIMATE2011', '804,307'),
#               ('POPESTIMATE2012', '858,356'),
#               ('POPESTIMATE2013', '858,578'),
#               ('POPESTIMATE2014', '867,417')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '78'),
#               ('POPESTIMATE2010', '799,410'),
#               ('POPESTIMATE2011', '792,305'),
#               ('POPESTIMATE2012', '779,426'),
#               ('POPESTIMATE2013', '831,820'),
#               ('POPESTIMATE2014', '832,296')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '79'),
#               ('POPESTIMATE2010', '781,029'),
#               ('POPESTIMATE2011', '771,137'),
#               ('POPESTIMATE2012', '765,134'),
#               ('POPESTIMATE2013', '752,584'),
#               ('POPESTIMATE2014', '803,512')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '80'),
#               ('POPESTIMATE2010', '770,510'),
#               ('POPESTIMATE2011', '750,281'),
#               ('POPESTIMATE2012', '741,646'),
#               ('POPESTIMATE2013', '735,913'),
#               ('POPESTIMATE2014', '724,040')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '81'),
#               ('POPESTIMATE2010', '716,534'),
#               ('POPESTIMATE2011', '736,838'),
#               ('POPESTIMATE2012', '718,324'),
#               ('POPESTIMATE2013', '710,017'),
#               ('POPESTIMATE2014', '704,919')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '82'),
#               ('POPESTIMATE2010', '695,545'),
#               ('POPESTIMATE2011', '681,520'),
#               ('POPESTIMATE2012', '701,905'),
#               ('POPESTIMATE2013', '684,193'),
#               ('POPESTIMATE2014', '676,658')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '83'),
#               ('POPESTIMATE2010', '658,442'),
#               ('POPESTIMATE2011', '657,400'),
#               ('POPESTIMATE2012', '645,144'),
#               ('POPESTIMATE2013', '664,442'),
#               ('POPESTIMATE2014', '648,016')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '84'),
#               ('POPESTIMATE2010', '611,339'),
#               ('POPESTIMATE2011', '617,782'),
#               ('POPESTIMATE2012', '617,909'),
#               ('POPESTIMATE2013', '606,278'),
#               ('POPESTIMATE2014', '624,921')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '85'),
#               ('POPESTIMATE2010', '577,353'),
#               ('POPESTIMATE2011', '568,684'),
#               ('POPESTIMATE2012', '576,049'),
#               ('POPESTIMATE2013', '576,128'),
#               ('POPESTIMATE2014', '565,705')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '86'),
#               ('POPESTIMATE2010', '526,155'),
#               ('POPESTIMATE2011', '532,096'),
#               ('POPESTIMATE2012', '525,354'),
#               ('POPESTIMATE2013', '532,248'),
#               ('POPESTIMATE2014', '532,762')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '87'),
#               ('POPESTIMATE2010', '467,575'),
#               ('POPESTIMATE2011', '479,814'),
#               ('POPESTIMATE2012', '486,706'),
#               ('POPESTIMATE2013', '480,494'),
#               ('POPESTIMATE2014', '487,380')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '88'),
#               ('POPESTIMATE2010', '420,437'),
#               ('POPESTIMATE2011', '421,484'),
#               ('POPESTIMATE2012', '434,001'),
#               ('POPESTIMATE2013', '440,357'),
#               ('POPESTIMATE2014', '435,171')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '89'),
#               ('POPESTIMATE2010', '365,732'),
#               ('POPESTIMATE2011', '373,960'),
#               ('POPESTIMATE2012', '376,615'),
#               ('POPESTIMATE2013', '387,915'),
#               ('POPESTIMATE2014', '394,150')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '90'),
#               ('POPESTIMATE2010', '306,925'),
#               ('POPESTIMATE2011', '320,856'),
#               ('POPESTIMATE2012', '329,447'),
#               ('POPESTIMATE2013', '332,066'),
#               ('POPESTIMATE2014', '342,495')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '91'),
#               ('POPESTIMATE2010', '240,152'),
#               ('POPESTIMATE2011', '264,951'),
#               ('POPESTIMATE2012', '278,572'),
#               ('POPESTIMATE2013', '285,972'),
#               ('POPESTIMATE2014', '288,866')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '92'),
#               ('POPESTIMATE2010', '205,379'),
#               ('POPESTIMATE2011', '203,922'),
#               ('POPESTIMATE2012', '226,170'),
#               ('POPESTIMATE2013', '238,106'),
#               ('POPESTIMATE2014', '244,659')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '93'),
#               ('POPESTIMATE2010', '158,881'),
#               ('POPESTIMATE2011', '171,165'),
#               ('POPESTIMATE2012', '171,179'),
#               ('POPESTIMATE2013', '189,749'),
#               ('POPESTIMATE2014', '200,353')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '94'),
#               ('POPESTIMATE2010', '126,947'),
#               ('POPESTIMATE2011', '129,530'),
#               ('POPESTIMATE2012', '140,916'),
#               ('POPESTIMATE2013', '141,196'),
#               ('POPESTIMATE2014', '156,525')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '95'),
#               ('POPESTIMATE2010', '99,341'),
#               ('POPESTIMATE2011', '101,448'),
#               ('POPESTIMATE2012', '104,220'),
#               ('POPESTIMATE2013', '113,692'),
#               ('POPESTIMATE2014', '114,300')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '96'),
#               ('POPESTIMATE2010', '75,139'),
#               ('POPESTIMATE2011', '77,458'),
#               ('POPESTIMATE2012', '79,997'),
#               ('POPESTIMATE2013', '82,067'),
#               ('POPESTIMATE2014', '89,949')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '97'),
#               ('POPESTIMATE2010', '54,118'),
#               ('POPESTIMATE2011', '57,164'),
#               ('POPESTIMATE2012', '59,557'),
#               ('POPESTIMATE2013', '61,693'),
#               ('POPESTIMATE2014', '63,252')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '98'),
#               ('POPESTIMATE2010', '37,533'),
#               ('POPESTIMATE2011', '40,110'),
#               ('POPESTIMATE2012', '42,876'),
#               ('POPESTIMATE2013', '44,703'),
#               ('POPESTIMATE2014', '46,536')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '99'),
#               ('POPESTIMATE2010', '26,074'),
#               ('POPESTIMATE2011', '27,034'),
#               ('POPESTIMATE2012', '29,321'),
#               ('POPESTIMATE2013', '31,378'),
#               ('POPESTIMATE2014', '32,791')]),
#  OrderedDict([('SEX', 'F'),
#               ('AGE', '100'),
#               ('POPESTIMATE2010', '45,058'),
#               ('POPESTIMATE2011', '47,557'),
#               ('POPESTIMATE2012', '50,684'),
#               ('POPESTIMATE2013', '54,379'),
#               ('POPESTIMATE2014', '58,468')])]
